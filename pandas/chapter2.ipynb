# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")#to read excel file use pd.read_excel("titanic.xls")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.columns.to_list() #list of columns name
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df[["Survived","Name"]]
# Out:
#      Survived                                          Name
# 0           0                              Kelly, Mr. James
# 1           1              Wilkes, Mrs. James (Ellen Needs)
# 2           0                     Myles, Mr. Thomas Francis
# 3           0                              Wirz, Mr. Albert
# 4           1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..        ...                                           ...
# 413         0                            Spector, Mr. Woolf
# 414         1                  Oliva y Ocana, Dona. Fermina
# 415         0                  Saether, Mr. Simon Sivertsen
# 416         0                           Ware, Mr. Frederick
# 417         0                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
df.iloc[:100]#first 100 records
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
df.loc[:99]#first 100 records
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
df.iloc[:5]#slicing
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.loc[:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.loc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# ...

# %% [markdown]
# ##### after loading the data, the first few steps
# 1. data.info()
# 2. data.describe()
# 3. data.head()

# %%
df.info()# here pandas  dtype object means str or mixed dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()#numerical col analysis(float and int)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.head()#first five records
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df.head(60)#max first 60
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
type(df.head)
# Out:
# method

# %%
df.tail()#last 5 records
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.tail(60)#max last 60 records can be viewed
# Out:
#      PassengerId  Survived  Pclass  \
# 358         1250         0       3
# 359         1251         1       3
# 360         1252         0       3
# 361         1253         1       2
# 362         1254         1       2
# 363         1255         0       3
# 364         1256         1       1
# 365         1257         1       3
# 366         1258         0       3
# 367         1259         1       3
# 368         1260         1       1
# 369         1261         0       2
# 370         1262         0       2
# 371         1263         1       1
# 372         1264         0       1
# 373         1265         0       2
# 374         1266         1       1
# 375         1267         1       1
# 376         1268         1       3
# 377         1269         0       2
# 378         1270         0       1
# 379         1271         0       3
# 380         1272         0       3
# 381         1273         0       3
# 382         1274         1       3
# ...

# %% [markdown]
# #### to access single series or column is called univariant analysis

# %%
df.loc[:10,"Survived"] #0 to 10 rows of data series Survived
#we cannot use iloc[] here
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    0
# Name: Survived, dtype: int64

# %%
df.Survived
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
df.Survived.value_counts().plot(kind="bar",color="teal")
# Out:
# <AxesSubplot: >

# %%
df.Survived.value_counts().plot(kind="pie",autopct="%.1f%%") # in % upto 1 decimal pace
# Out:
# <AxesSubplot: ylabel='Survived'>

# %%
df.Survived.value_counts().plot(kind="area") #an area chart is a combination of line and bar chart
# Out:
# <AxesSubplot: >

# %%
df.Pclass
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
df.Pclass.value_counts().plot(kind="pie",autopct="%.1f%%")
# Out:
# <AxesSubplot: ylabel='Pclass'>

# %%
df.Sex.value_counts().plot(kind="pie",autopct="%.1f%%")
# Out:
# <AxesSubplot: ylabel='Sex'>

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df.Name.nunique()#no. of unique values
# Out:
# 418

# %%
df.Embarked.unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
df.Fare.nunique()
# Out:
# 169

# %%
df.groupby("Survived")["Sex","Pclass"].value_counts()
# Out:
# C:\Users\Zeenat jahan\AppData\Local\Temp\ipykernel_30252\2423779353.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Survived")["Sex","Pclass"].value_counts()
# Survived  Sex     Pclass
# 0         male    3         146
#                   2          63
#                   1          57
# 1         female  3          72
#                   1          50
#                   2          30
# dtype: int64

# %%
df.groupby(["Survived","Sex"]).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Survived Sex
# 0        male            266     266   266  205    266    266     266   265
# 1        female          152     152   152  127    152    152     152   152
#
#                  Cabin  Embarked
# Survived Sex
# 0        male       47       266
# 1        female     44       152

# %%
df.Fare
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
df.Fare.mean()
# Out:
# 35.627188489208635

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df.Fare.sum()
# Out:
# 14856.5376

# %%
df.Fare.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.Fare.plot(figsize=(20,5))#line chart
# Out:
# <AxesSubplot: >

# %%
df.Fare.plot(figsize=(20,5),kind="area")#here bar chart will give clear vision of data
# Out:
# <AxesSubplot: >

# %%
df.pivot_table(index="Pclass",values="Fare",aggfunc="sum")
# Out:
#               Fare
# Pclass
# 1       10087.9918
# 2        2064.7957
# 3        2703.7501

# %%
df.pivot_table(index="Pclass",values="Fare",aggfunc="sum").plot(
   kind="pie",autopct="%.1f%%",subplots=True
    )
# Out:
# array([<AxesSubplot: ylabel='Fare'>], dtype=object)

# %%
df.pivot_table(index="Pclass",values="Fare",aggfunc="mean").plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Pclass'>
