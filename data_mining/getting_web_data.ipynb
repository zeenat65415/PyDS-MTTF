# %%
import requests

# %%
url = "https://www.google.com/about"
web_page=requests.get(url)
print(web_page.status_code)
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(web_page.content)
print(soup.prettify())#print the html code for testing
# Out:
# <!DOCTYPE html>
# <html class="google glue-flexbox spa" dir="ltr" lang="en" locale="ALL_in" path="/" user-region="asia-pacific">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="initial-scale=1, minimum-scale=1, width=device-width" name="viewport"/>
#   <title>
#    Google - About Google, Our Culture &amp; Company News
#   </title>
#   <meta content="Stay up to date with Google company news and products. Discover stories about our culture, philosophy, and how Google technology is impacting others." name="description"/>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
# window.dataLayer.push({
#    'gtm.blacklist':['customScripts','nonGoogleScripts','nonGooglePixels','customPixels']
# },{
#    'locale_fallback': (document.childNodes[1].attributes.locale || {}).value
# });
#   </script>
#   <!-- Google Tag Manager -->
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WQZB4J');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw">
#    window.dataLayer.push({
#     event: 'coinToss5050',
#     action: Math.random() > .5 ? 'group1': 'group2'
# });
#   </script>
#   <link href="//fonts.googleapis.com/css?family=Roboto:100,300,400,500,700|Google+Sans+Text:400,500,700,400i,500i,700i|Google+Sans:400,500|Google+Sans+Display:400|Product+Sans:400&amp;lang=en" nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" rel="stylesheet"/>
#   <link href="/assets/css/main.min.css?cache=fb655d0" nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" rel="stylesheet"/>
#   <meta content="Stay up to date with Google company news and products. Discover stories about our culture, philosophy, and how Google technology is impacting others." property="og:description"/>
#   <meta content="Google - About Google, Our Culture &amp; Company News" property="og:title"/>
#   <meta content="https://lh3.googleusercontent.com/uXVic9jyqJADV4C98TjSkFX-3xxJYedpS2hce6adkNw0t7St_qPHNfhqk6XCUTlF31Pe1v64f0Oc640_0daNO6Ql0UU7_D9yYkz9=w600-l80-sg-rj" property="og:image"/>
#   <meta content="600" property="og:image:width"/>
#   <meta content="315" property="og:image:height"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://about.google/intl/ALL_in/" property="og:url"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@google" name="twitter:site"/>
#   <meta content="Google - About Google, Our Culture &amp; Company News" name="twitter:title"/>
#   <meta content="Curious about Google? Learn more about Google’s history, values, people, and technology." name="twitter:description"/>
#   <meta content="https://lh3.googleusercontent.com/uXVic9jyqJADV4C98TjSkFX-3xxJYedpS2hce6adkNw0t7St_qPHNfhqk6XCUTlF31Pe1v64f0Oc640_0daNO6Ql0UU7_D9yYkz9=w600-l80-sg-rj" name="twitter:image"/>
#   <meta content="ALL_in" property="google:search-sre-monitor"/>
#   <link href="https://www.gstatic.com/images/branding/googleg/2x/googleg_standard_color_120dp.png" rel="apple-touch-icon"/>
#   <link href="https://www.gstatic.com/images/branding/googleg/2x/googleg_standard_color_120dp.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://about.google/intl/ALL_in/" rel="canonical"/>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw">
#    (function(){document.documentElement.classList.remove("google");document.documentElement.classList.add("google-js");}).call(window)
#   </script>
#  </head>
#  <body data-ng-controller="MainCtrl as mainCtrl">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WQZB4J" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <header class="header" data-about-nav="" data-ng-class="{'header--dark-bg': navCtrl.navIsDark, 'header--custom-color': navCtrl.navCustomColor, 'header--inactive': navCtrl.navIsFixed}">
#    <a class="jump-link" href="#content">
#     Jump to content
#    </a>
#    <div class="header-inner">
#     <button aria-label="Navigation menu toggle" class="nav-toggle-button outside" data-about-nav-toggle="" data-g-action="navigation" data-g-category="header" data-g-label="Navigation menu toggle" data-g-module-type="Main Nav">
#      <svg alt="Open navigation menu" class="menu-bars" height="24px" viewBox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg">
#       <path d="M3 18h18v-2H3v2zm0-5h18v-2H3v2zm0-7v2h18V6H3z">
#       </path>
#      </svg>
#      <img alt="Open navigation menu" class="menu-bars" height="24" src="/assets/img/menu.png?cache=38c6aed" width="24"/>
#      <svg alt="Close navigation menu" class="menu-close" height="24px" viewBox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg">
#       <path d="M19 6.41L17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12z">
#       </path>
#      </svg>
#      <img alt="Close navigation menu" class="menu-close" height="24" src="/assets/img/close.png?cache=5628868" width="24"/>
#     </button>
#     <div class="product-logo">
#      <a aria-label="Google" data-g-action="google logo" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="./" target="_self">
#       <svg alt="Google" class="logo-svg" viewBox="0 0 74 24" xmlns="http://www.w3.org/2000/svg">
#        <path d="M9.24 8.19v2.46h5.88c-.18 1.38-.64 2.39-1.34 3.1-.86.86-2.2 1.8-4.54 1.8-3.62 0-6.45-2.92-6.45-6.54s2.83-6.54 6.45-6.54c1.95 0 3.38.77 4.43 1.76L15.4 2.5C13.94 1.08 11.98 0 9.24 0 4.28 0 .11 4.04.11 9s4.17 9 9.13 9c2.68 0 4.7-.88 6.28-2.52 1.62-1.62 2.13-3.91 2.13-5.75 0-.57-.04-1.1-.13-1.54H9.24z" fill="#4285F4">
#        </path>
#        <path d="M25 6.19c-3.21 0-5.83 2.44-5.83 5.81 0 3.34 2.62 5.81 5.83 5.81s5.83-2.46 5.83-5.81c0-3.37-2.62-5.81-5.83-5.81zm0 9.33c-1.76 0-3.28-1.45-3.28-3.52 0-2.09 1.52-3.52 3.28-3.52s3.28 1.43 3.28 3.52c0 2.07-1.52 3.52-3.28 3.52z" fill="#EA4335">
#        </path>
#        <path d="M53.58 7.49h-.09c-.57-.68-1.67-1.3-3.06-1.3C47.53 6.19 45 8.72 45 12c0 3.26 2.53 5.81 5.43 5.81 1.39 0 2.49-.62 3.06-1.32h.09v.81c0 2.22-1.19 3.41-3.1 3.41-1.56 0-2.53-1.12-2.93-2.07l-2.22.92c.64 1.54 2.33 3.43 5.15 3.43 2.99 0 5.52-1.76 5.52-6.05V6.49h-2.42v1zm-2.93 8.03c-1.76 0-3.1-1.5-3.1-3.52 0-2.05 1.34-3.52 3.1-3.52 1.74 0 3.1 1.5 3.1 3.54.01 2.03-1.36 3.5-3.1 3.5z" fill="#4285F4">
#        </path>
#        <path d="M38 6.19c-3.21 0-5.83 2.44-5.83 5.81 0 3.34 2.62 5.81 5.83 5.81s5.83-2.46 5.83-5.81c0-3.37-2.62-5.81-5.83-5.81zm0 9.33c-1.76 0-3.28-1.45-3.28-3.52 0-2.09 1.52-3.52 3.28-3.52s3.28 1.43 3.28 3.52c0 2.07-1.52 3.52-3.28 3.52z" fill="#FBBC05">
#        </path>
#        <path d="M58 .24h2.51v17.57H58z" fill="#34A853">
#        </path>
#        <path d="M68.26 15.52c-1.3 0-2.22-.59-2.82-1.76l7.77-3.21-.26-.66c-.48-1.3-1.96-3.7-4.97-3.7-2.99 0-5.48 2.35-5.48 5.81 0 3.26 2.46 5.81 5.76 5.81 2.66 0 4.2-1.63 4.84-2.57l-1.98-1.32c-.66.96-1.56 1.6-2.86 1.6zm-.18-7.15c1.03 0 1.91.53 2.2 1.28l-5.25 2.17c0-2.44 1.73-3.45 3.05-3.45z" fill="#EA4335">
#        </path>
#       </svg>
#      </a>
#     </div>
#     <nav class="top-nav">
#      <div class="product-logo">
#       <a data-g-action="google logo" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="./" target="_self">
#        <svg alt="Google" class="logo-svg" viewBox="0 0 74 24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M9.24 8.19v2.46h5.88c-.18 1.38-.64 2.39-1.34 3.1-.86.86-2.2 1.8-4.54 1.8-3.62 0-6.45-2.92-6.45-6.54s2.83-6.54 6.45-6.54c1.95 0 3.38.77 4.43 1.76L15.4 2.5C13.94 1.08 11.98 0 9.24 0 4.28 0 .11 4.04.11 9s4.17 9 9.13 9c2.68 0 4.7-.88 6.28-2.52 1.62-1.62 2.13-3.91 2.13-5.75 0-.57-.04-1.1-.13-1.54H9.24z" fill="#4285F4">
#         </path>
#         <path d="M25 6.19c-3.21 0-5.83 2.44-5.83 5.81 0 3.34 2.62 5.81 5.83 5.81s5.83-2.46 5.83-5.81c0-3.37-2.62-5.81-5.83-5.81zm0 9.33c-1.76 0-3.28-1.45-3.28-3.52 0-2.09 1.52-3.52 3.28-3.52s3.28 1.43 3.28 3.52c0 2.07-1.52 3.52-3.28 3.52z" fill="#EA4335">
#         </path>
#         <path d="M53.58 7.49h-.09c-.57-.68-1.67-1.3-3.06-1.3C47.53 6.19 45 8.72 45 12c0 3.26 2.53 5.81 5.43 5.81 1.39 0 2.49-.62 3.06-1.32h.09v.81c0 2.22-1.19 3.41-3.1 3.41-1.56 0-2.53-1.12-2.93-2.07l-2.22.92c.64 1.54 2.33 3.43 5.15 3.43 2.99 0 5.52-1.76 5.52-6.05V6.49h-2.42v1zm-2.93 8.03c-1.76 0-3.1-1.5-3.1-3.52 0-2.05 1.34-3.52 3.1-3.52 1.74 0 3.1 1.5 3.1 3.54.01 2.03-1.36 3.5-3.1 3.5z" fill="#4285F4">
#         </path>
#         <path d="M38 6.19c-3.21 0-5.83 2.44-5.83 5.81 0 3.34 2.62 5.81 5.83 5.81s5.83-2.46 5.83-5.81c0-3.37-2.62-5.81-5.83-5.81zm0 9.33c-1.76 0-3.28-1.45-3.28-3.52 0-2.09 1.52-3.52 3.28-3.52s3.28 1.43 3.28 3.52c0 2.07-1.52 3.52-3.28 3.52z" fill="#FBBC05">
#         </path>
#         <path d="M58 .24h2.51v17.57H58z" fill="#34A853">
#         </path>
#         <path d="M68.26 15.52c-1.3 0-2.22-.59-2.82-1.76l7.77-3.21-.26-.66c-.48-1.3-1.96-3.7-4.97-3.7-2.99 0-5.48 2.35-5.48 5.81 0 3.26 2.46 5.81 5.76 5.81 2.66 0 4.2-1.63 4.84-2.57l-1.98-1.32c-.66.96-1.56 1.6-2.86 1.6zm-.18-7.15c1.03 0 1.91.53 2.2 1.28l-5.25 2.17c0-2.44 1.73-3.45 3.05-3.45z" fill="#EA4335">
#         </path>
#        </svg>
#       </a>
#      </div>
#      <ul class="main-nav" role="menu">
#       <li class="selected-page _-home" id="tab-1" role="none">
#        <a class="header-link-home" data-g-action="home" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="./" role="menuitem" target="_self">
#         About
#        </a>
#       </li>
#       <li class="_-products" id="tab-2" role="none">
#        <a class="header-link-products" data-g-action="products" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="./products/" role="menuitem" target="_self">
#         Products
#        </a>
#       </li>
#       <li class="_-commitments" id="tab-3" role="none">
#        <a class="header-link-commitments" data-g-action="commitments" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="./commitments/" role="menuitem" target="_self">
#         Commitments
#        </a>
#       </li>
#       <li class="_-stories" id="tab-4" role="none">
#        <a class="header-link-stories" data-g-action="stories" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="./stories/" role="menuitem" target="_self">
#         Stories
#        </a>
#       </li>
#       <li class="_-blog" id="tab-5" role="none">
#        <a class="header-link-blog" data-g-action="blog" data-g-category="site navigation" data-g-label="header" data-g-nav-link="" href="https://india.googleblog.com/" role="menuitem" target="_blank">
#         India Blog
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </div>
#   </header>
#   <main class="static-content-view" data-ui-view="main" id="content">
#    <div class="modular-page modular-page-homepage" data-page-description="Stay up to date with Google company news and products. Discover stories about our culture, philosophy, and how Google technology is impacting others." data-page-title="Google - About Google, Our Culture &amp; Company News" data-track-page-load="">
#     <section class="module-spacer">
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#     </section>
#     <section class="module-anchor-statement center module-anchor-statement__header-one" data-section-id="mission-statement" id="module-anchor-statement-mission-statement">
#      <div>
#       <h1>
#        Our mission is to
#        <span class="blue">
#         organise
#        </span>
#        the world’s
#        <span class="red">
#         information
#        </span>
#        and make it
#        <span class="green">
#         universally accessible
#        </span>
#        and
#        <span class="yellow">
#         useful
#        </span>
#        .
#       </h1>
#      </div>
#     </section>
#     <section class="module module-section h-c-page module-large-tile center" data-add-class-on-show="-visible" data-add-class-threshold="100vh" data-section-id="iwd-tile">
#      <a class="module-large-tile__link" href="./stories/accelerating-equity-for-women/" target="_self">
#       <div class="module-large-tile__container card-light iwd-tile">
#        <div class="module-large-tile__desktop-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-7e326ee {
#           background-image: url(https://lh3.googleusercontent.com/wgbKzzdnrcakLSgwa5J15onKTun_C7V_SwOKjWIdGljX_ms4C1xRozUlqaBP-fc1qVVDK-9tWkHT-qxCRw2yv28xUNAuvHctyfrRcQ1fQdZB698owg=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-7e326ee {
#             background-image: url(https://lh3.googleusercontent.com/wgbKzzdnrcakLSgwa5J15onKTun_C7V_SwOKjWIdGljX_ms4C1xRozUlqaBP-fc1qVVDK-9tWkHT-qxCRw2yv28xUNAuvHctyfrRcQ1fQdZB698owg=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-7e326ee {
#           background-image: url(https://lh3.googleusercontent.com/wgbKzzdnrcakLSgwa5J15onKTun_C7V_SwOKjWIdGljX_ms4C1xRozUlqaBP-fc1qVVDK-9tWkHT-qxCRw2yv28xUNAuvHctyfrRcQ1fQdZB698owg=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-7e326ee {
#             background-image: url(https://lh3.googleusercontent.com/wgbKzzdnrcakLSgwa5J15onKTun_C7V_SwOKjWIdGljX_ms4C1xRozUlqaBP-fc1qVVDK-9tWkHT-qxCRw2yv28xUNAuvHctyfrRcQ1fQdZB698owg=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-7e326ee {
#           background-image: url(https://lh3.googleusercontent.com/wgbKzzdnrcakLSgwa5J15onKTun_C7V_SwOKjWIdGljX_ms4C1xRozUlqaBP-fc1qVVDK-9tWkHT-qxCRw2yv28xUNAuvHctyfrRcQ1fQdZB698owg=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-7e326ee {
#             background-image: url(https://lh3.googleusercontent.com/wgbKzzdnrcakLSgwa5J15onKTun_C7V_SwOKjWIdGljX_ms4C1xRozUlqaBP-fc1qVVDK-9tWkHT-qxCRw2yv28xUNAuvHctyfrRcQ1fQdZB698owg=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-7e326ee">
#          <div class="gradient-overlay">
#          </div>
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-7e326ee">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__mobile-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-2cc5a74 {
#           background-image: url(https://lh3.googleusercontent.com/VMpOm2IXHNNYmZDStle87tOdv0DQqwUSkRnTd8lkdBby9ZOU1CLjYxVUZZ1hT5lI08c1E2BDNQcvrY90jxDuA1b3JbRm3DYDt0QWOJe_tt0UIQ3bNA=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-2cc5a74 {
#             background-image: url(https://lh3.googleusercontent.com/VMpOm2IXHNNYmZDStle87tOdv0DQqwUSkRnTd8lkdBby9ZOU1CLjYxVUZZ1hT5lI08c1E2BDNQcvrY90jxDuA1b3JbRm3DYDt0QWOJe_tt0UIQ3bNA=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-2cc5a74 {
#           background-image: url(https://lh3.googleusercontent.com/VMpOm2IXHNNYmZDStle87tOdv0DQqwUSkRnTd8lkdBby9ZOU1CLjYxVUZZ1hT5lI08c1E2BDNQcvrY90jxDuA1b3JbRm3DYDt0QWOJe_tt0UIQ3bNA=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-2cc5a74 {
#             background-image: url(https://lh3.googleusercontent.com/VMpOm2IXHNNYmZDStle87tOdv0DQqwUSkRnTd8lkdBby9ZOU1CLjYxVUZZ1hT5lI08c1E2BDNQcvrY90jxDuA1b3JbRm3DYDt0QWOJe_tt0UIQ3bNA=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-2cc5a74 {
#           background-image: url(https://lh3.googleusercontent.com/VMpOm2IXHNNYmZDStle87tOdv0DQqwUSkRnTd8lkdBby9ZOU1CLjYxVUZZ1hT5lI08c1E2BDNQcvrY90jxDuA1b3JbRm3DYDt0QWOJe_tt0UIQ3bNA=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-2cc5a74 {
#             background-image: url(https://lh3.googleusercontent.com/VMpOm2IXHNNYmZDStle87tOdv0DQqwUSkRnTd8lkdBby9ZOU1CLjYxVUZZ1hT5lI08c1E2BDNQcvrY90jxDuA1b3JbRm3DYDt0QWOJe_tt0UIQ3bNA=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-2cc5a74">
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-2cc5a74">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__text-container">
#         <p class="module-large-tile__eyebrow">
#          International Women’s Day
#         </p>
#         <h4 class="module-large-tile__headline" data-unite-orphan="">
#          A closer look at the journey to help accelerate equity and representation for women at Google and beyond
#         </h4>
#         <p class="module-large-tile__cta">
#          Learn more
#         </p>
#        </div>
#       </div>
#      </a>
#     </section>
#     <section class="module module-section module-social-feed" data-news-feeds='[ { "type": "Blogger", "url": "https://www.googleapis.com/blogger/v3/blogs/6296508887730508910/posts/?key=AIzaSyBOfS0TlKoXQ-KdZFJ6RLijF7cjE8Uon04&amp;fields=items(author%2Ccontent%2Cid%2Ctitle%2Cpublished%2Cupdated%2Curl)&amp;maxResults=4" }  ]' data-ng-controller="NewsFeedCtrl as newsFeedCtrl" data-section-id="news-feed-1" ng-hide="newsFeedCtrl.feedErrorOrEmpty">
#      <h2 class="section-title">
#       Company news
#      </h2>
#      <div class="carousel-placeholder">
#       <div class="carousel-container homepage-prototype" style="display: none;">
#        <ul>
#         <li class="carousel-slide" data-ng-class="[feed.type, feed.network_class, feed.account_slug, {'no-post-image': !feed.image}]" ng-repeat="feed in newsFeedCtrl.feed | limitTo:4">
#          <div class="carousel-slide-inner">
#           <a class="post-link" data-g-action="social feed" data-g-category="about us" data-g-href="{[::feed.url]}" data-g-label="share:{[::feed.url]}" data-ng-href="{[::feed.url]}" target="_blank">
#            <div class="carousel-slide-media carousel-slide-bg image-placeholder" data-ng-if="!feed.image &amp;&amp; !feed.video">
#             <img class="{[::feed.type]}" data-ng-src="/assets/img/{[feed.image_generic]}"/>
#             <div class="account-name" data-ng-if="feed.type == 'social'">
#              {['@']}{[::feed.account | stripSpaces]}
#             </div>
#            </div>
#            <div class="carousel-slide-media carousel-slide-bg" data-ng-if="feed.image &amp;&amp; (!feed.video || !mainCtrl.detect.INLINE_VIDEO)" style="background-image:url({[::feed.image]})">
#             <img class="{[::feed.type]} backup-image" data-ng-src="/assets/img/blog-fallback-3.svg"/>
#            </div>
#            <div class="carousel-slide-media video-container" data-ng-if="feed.video &amp;&amp; mainCtrl.detect.INLINE_VIDEO">
#             <video autoplay="" data-mute-video="" data-ng-if="feed.video" data-ng-src="{[::feed.video]}" height="100%" loop="" width="100%">
#              <!---->
#             </video>
#            </div>
#            <div class="carousel-slide-content">
#             <div class="icon-outer" data-ng-if="feed.type == 'social'">
#              <img alt="" class="icon icon-logo" data-ng-src="/assets/img/social-{[::feed.icon]}-color.svg"/>
#             </div>
#             <div class="post-header">
#              <span class="blog account no-wrap" data-ng-if="feed.type == 'blog'">
#               {[feed.account]}
#              </span>
#              <span class="account no-wrap" data-ng-if="feed.type == 'social'">
#               {['@']}{[::feed.account | stripSpaces]}
#              </span>
#             </div>
#             <div class="post-footer" data-ng-bind-html="feed.title | socialLink:feed.network" data-target-blank="">
#              <!---->
#             </div>
#             <div class="post-date">
#              {[::feed.published_at|date:'mediumDate']}
#             </div>
#            </div>
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="glue-pagination carousel-container" data-ng-cloak="" data-ng-if="newsFeedCtrl.dataReady" glue-pagination-model="mainCtrl.getPaginationModel('')">
#        <div class="carousel-peeking">
#         <ul class="glue-carousel" data-carousel-tracking="" data-glue-carousel-options="mainCtrl.carouselOptions" glue-carousel-disable="false">
#          <li class="carousel-slide" data-glue-carousel-repeat="feed in ::newsFeedCtrl.feed" data-ng-class="[feed.type, feed.network_class, feed.account_slug, {'no-post-image': !feed.image}]">
#           <div class="carousel-slide-inner">
#            <a class="post-link" data-g-action="social feed" data-g-category="about us" data-g-href="{[::feed.url]}" data-g-label="share:{[::feed.url]}" data-ng-href="{[::feed.url]}" target="_blank">
#             <div class="carousel-slide-media carousel-slide-bg image-placeholder" data-ng-if="!feed.image &amp;&amp; !feed.video">
#              <img class="{[::feed.type]}" data-ng-src="/assets/img/{[feed.image_generic]}"/>
#              <div class="account-name" data-ng-if="feed.type == 'social'">
#               {['@']}{[::feed.account | stripSpaces]}
#              </div>
#             </div>
#             <div class="carousel-slide-media carousel-slide-bg" data-ng-if="feed.image &amp;&amp; (!feed.video || !mainCtrl.detect.INLINE_VIDEO)" style="background-image:url({[::feed.image]})">
#              <img class="{[::feed.type]} backup-image" data-ng-src="/assets/img/blog-fallback-3.svg"/>
#             </div>
#             <div class="carousel-slide-media video-container" data-ng-if="feed.video &amp;&amp; mainCtrl.detect.INLINE_VIDEO">
#              <video autoplay="" data-mute-video="" data-ng-if="feed.video" data-ng-src="{[::feed.video]}" height="100%" loop="" width="100%">
#               <!---->
#              </video>
#             </div>
#             <div class="carousel-slide-content">
#              <div class="icon-outer" data-ng-if="feed.type == 'social'">
#               <img alt="" class="icon icon-logo" data-ng-src="/assets/img/social-{[::feed.icon]}-color.svg"/>
#              </div>
#              <div class="post-header">
#               <span class="blog account no-wrap" data-ng-if="feed.type == 'blog'">
#                {[feed.account]}
#               </span>
#               <span class="account no-wrap" data-ng-if="feed.type == 'social'">
#                {['@']}{[::feed.account | stripSpaces]}
#               </span>
#              </div>
#              <div class="post-footer" data-ng-bind-html="feed.title | socialLink:feed.network" data-target-blank="">
#               <!---->
#              </div>
#             </div>
#            </a>
#           </div>
#           <div class="post-date">
#            {[::feed.published_at|date:'mediumDate']}
#           </div>
#          </li>
#         </ul>
#        </div>
#        <div class="carousel-nav-arrows">
#         <div class="glue-pagination-previous" data-g-action="navigation" data-g-category="about us" data-g-label="Carousel: scroll previous" data-glue-pagination-update-model="false">
#          <img alt="Previous" src="/assets/img/keyboard-arrow-up-999.svg?cache=911336e"/>
#         </div>
#         <div class="glue-pagination-next" data-g-action="navigation" data-g-category="about us" data-g-label="Carousel: scroll next" data-glue-pagination-update-model="false">
#          <img alt="Next" src="/assets/img/keyboard-arrow-up-999.svg?cache=911336e"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="module-spacer">
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#     </section>
#     <section class="module module-section h-c-page module-large-tile center" data-add-class-on-show="-visible" data-add-class-threshold="100vh" data-section-id="our-products-helpful-tile">
#      <a class="module-large-tile__link" href="products" target="_self">
#       <div class="module-large-tile__container card-dark our-products-helpful-tile">
#        <div class="module-large-tile__desktop-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-3cde1cd {
#           background-image: url(https://lh3.googleusercontent.com/dtm-uATUnHmnlQBAA9F2PmD3kvKSkyoGi7MmtVwAeY_ESQLZnVDsNSCgIi-lk24BfQQN61tYvHZvu1oaec1yPhqnZudKkuV2SDPre28=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-3cde1cd {
#             background-image: url(https://lh3.googleusercontent.com/dtm-uATUnHmnlQBAA9F2PmD3kvKSkyoGi7MmtVwAeY_ESQLZnVDsNSCgIi-lk24BfQQN61tYvHZvu1oaec1yPhqnZudKkuV2SDPre28=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-3cde1cd {
#           background-image: url(https://lh3.googleusercontent.com/dtm-uATUnHmnlQBAA9F2PmD3kvKSkyoGi7MmtVwAeY_ESQLZnVDsNSCgIi-lk24BfQQN61tYvHZvu1oaec1yPhqnZudKkuV2SDPre28=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-3cde1cd {
#             background-image: url(https://lh3.googleusercontent.com/dtm-uATUnHmnlQBAA9F2PmD3kvKSkyoGi7MmtVwAeY_ESQLZnVDsNSCgIi-lk24BfQQN61tYvHZvu1oaec1yPhqnZudKkuV2SDPre28=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-3cde1cd {
#           background-image: url(https://lh3.googleusercontent.com/dtm-uATUnHmnlQBAA9F2PmD3kvKSkyoGi7MmtVwAeY_ESQLZnVDsNSCgIi-lk24BfQQN61tYvHZvu1oaec1yPhqnZudKkuV2SDPre28=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-3cde1cd {
#             background-image: url(https://lh3.googleusercontent.com/dtm-uATUnHmnlQBAA9F2PmD3kvKSkyoGi7MmtVwAeY_ESQLZnVDsNSCgIi-lk24BfQQN61tYvHZvu1oaec1yPhqnZudKkuV2SDPre28=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-3cde1cd">
#          <div class="gradient-overlay">
#          </div>
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-3cde1cd">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__mobile-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-627adbd {
#           background-image: url(https://lh3.googleusercontent.com/pMC_HgbmB-tD7XJvVupR0svqK4FOYkGYeIfFkngdr6qnzkBPUZi5Kv39QGNt1Yp-McHhNTn5jP767-z_CI7XQcxdaKWPeRFC82UI3Q=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-627adbd {
#             background-image: url(https://lh3.googleusercontent.com/pMC_HgbmB-tD7XJvVupR0svqK4FOYkGYeIfFkngdr6qnzkBPUZi5Kv39QGNt1Yp-McHhNTn5jP767-z_CI7XQcxdaKWPeRFC82UI3Q=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-627adbd {
#           background-image: url(https://lh3.googleusercontent.com/pMC_HgbmB-tD7XJvVupR0svqK4FOYkGYeIfFkngdr6qnzkBPUZi5Kv39QGNt1Yp-McHhNTn5jP767-z_CI7XQcxdaKWPeRFC82UI3Q=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-627adbd {
#             background-image: url(https://lh3.googleusercontent.com/pMC_HgbmB-tD7XJvVupR0svqK4FOYkGYeIfFkngdr6qnzkBPUZi5Kv39QGNt1Yp-McHhNTn5jP767-z_CI7XQcxdaKWPeRFC82UI3Q=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-627adbd {
#           background-image: url(https://lh3.googleusercontent.com/pMC_HgbmB-tD7XJvVupR0svqK4FOYkGYeIfFkngdr6qnzkBPUZi5Kv39QGNt1Yp-McHhNTn5jP767-z_CI7XQcxdaKWPeRFC82UI3Q=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-627adbd {
#             background-image: url(https://lh3.googleusercontent.com/pMC_HgbmB-tD7XJvVupR0svqK4FOYkGYeIfFkngdr6qnzkBPUZi5Kv39QGNt1Yp-McHhNTn5jP767-z_CI7XQcxdaKWPeRFC82UI3Q=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-627adbd">
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-627adbd">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__text-container">
#         <p class="module-large-tile__eyebrow">
#          Our Products
#         </p>
#         <h4 class="module-large-tile__headline" data-unite-orphan="">
#          Hi, how can we help?
#         </h4>
#         <p class="module-large-tile__cta">
#          See what we build
#         </p>
#        </div>
#       </div>
#      </a>
#     </section>
#     <section class="module-spacer">
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#     </section>
#     <section class="module module-section h-c-page module-large-tile center" data-add-class-on-show="-visible" data-add-class-threshold="100vh" data-section-id="our-commitments-tile">
#      <a class="module-large-tile__link" href="commitments" target="_self">
#       <div class="module-large-tile__container card-light our-commitments-tile">
#        <div class="module-large-tile__desktop-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-3bfc633 {
#           background-image: url(https://lh3.googleusercontent.com/ezebhzrjRsWrx_LeS0BGaneK1LsE55jCMiXpKNlP9TpMYPDRNLTI3vRzGa7O2Ow95JBR-mzJ7K-qBf70NX7EjHwbELv-5aviOdZKOv8=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-3bfc633 {
#             background-image: url(https://lh3.googleusercontent.com/ezebhzrjRsWrx_LeS0BGaneK1LsE55jCMiXpKNlP9TpMYPDRNLTI3vRzGa7O2Ow95JBR-mzJ7K-qBf70NX7EjHwbELv-5aviOdZKOv8=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-3bfc633 {
#           background-image: url(https://lh3.googleusercontent.com/ezebhzrjRsWrx_LeS0BGaneK1LsE55jCMiXpKNlP9TpMYPDRNLTI3vRzGa7O2Ow95JBR-mzJ7K-qBf70NX7EjHwbELv-5aviOdZKOv8=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-3bfc633 {
#             background-image: url(https://lh3.googleusercontent.com/ezebhzrjRsWrx_LeS0BGaneK1LsE55jCMiXpKNlP9TpMYPDRNLTI3vRzGa7O2Ow95JBR-mzJ7K-qBf70NX7EjHwbELv-5aviOdZKOv8=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-3bfc633 {
#           background-image: url(https://lh3.googleusercontent.com/ezebhzrjRsWrx_LeS0BGaneK1LsE55jCMiXpKNlP9TpMYPDRNLTI3vRzGa7O2Ow95JBR-mzJ7K-qBf70NX7EjHwbELv-5aviOdZKOv8=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-3bfc633 {
#             background-image: url(https://lh3.googleusercontent.com/ezebhzrjRsWrx_LeS0BGaneK1LsE55jCMiXpKNlP9TpMYPDRNLTI3vRzGa7O2Ow95JBR-mzJ7K-qBf70NX7EjHwbELv-5aviOdZKOv8=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-3bfc633">
#          <div class="gradient-overlay">
#          </div>
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-3bfc633">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__mobile-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-afb2985 {
#           background-image: url(https://lh3.googleusercontent.com/aTSyBWpDNZZdi15uDJ-OGEdGZklydXde-58FoYT2ZlNA9Nsv-eL7fmQ18OH6CJixUFTiE_NRi76KIKRdgYkZamcuRRLVivJSQSkYNg=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-afb2985 {
#             background-image: url(https://lh3.googleusercontent.com/aTSyBWpDNZZdi15uDJ-OGEdGZklydXde-58FoYT2ZlNA9Nsv-eL7fmQ18OH6CJixUFTiE_NRi76KIKRdgYkZamcuRRLVivJSQSkYNg=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-afb2985 {
#           background-image: url(https://lh3.googleusercontent.com/aTSyBWpDNZZdi15uDJ-OGEdGZklydXde-58FoYT2ZlNA9Nsv-eL7fmQ18OH6CJixUFTiE_NRi76KIKRdgYkZamcuRRLVivJSQSkYNg=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-afb2985 {
#             background-image: url(https://lh3.googleusercontent.com/aTSyBWpDNZZdi15uDJ-OGEdGZklydXde-58FoYT2ZlNA9Nsv-eL7fmQ18OH6CJixUFTiE_NRi76KIKRdgYkZamcuRRLVivJSQSkYNg=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-afb2985 {
#           background-image: url(https://lh3.googleusercontent.com/aTSyBWpDNZZdi15uDJ-OGEdGZklydXde-58FoYT2ZlNA9Nsv-eL7fmQ18OH6CJixUFTiE_NRi76KIKRdgYkZamcuRRLVivJSQSkYNg=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-afb2985 {
#             background-image: url(https://lh3.googleusercontent.com/aTSyBWpDNZZdi15uDJ-OGEdGZklydXde-58FoYT2ZlNA9Nsv-eL7fmQ18OH6CJixUFTiE_NRi76KIKRdgYkZamcuRRLVivJSQSkYNg=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-afb2985">
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-afb2985">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__text-container">
#         <p class="module-large-tile__eyebrow">
#          Our Commitments
#         </p>
#         <h4 class="module-large-tile__headline" data-unite-orphan="">
#          Dedicated to improving people’s lives. As true today as it was at the start.
#         </h4>
#         <p class="module-large-tile__cta">
#          How we contribute
#         </p>
#        </div>
#       </div>
#      </a>
#     </section>
#     <section class="module-spacer">
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#     </section>
#     <section class="module module-section h-c-page module-large-tile center" data-add-class-on-show="-visible" data-add-class-threshold="100vh" data-section-id="our-stories-tile">
#      <a class="module-large-tile__link" href="stories" target="_self">
#       <div class="module-large-tile__container card-light our-stories-tile">
#        <div class="module-large-tile__desktop-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-b94c682 {
#           background-image: url(https://lh3.googleusercontent.com/eld5nhFKpjO9nWYVQuciJ1KLeTZQwiVfSVtZFNcb-njiDY4KNCa5IoK5e3xIVbNI0CILlE57S3Dkj5C7LvCSEmIkGYhoynN9FasHdA=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-b94c682 {
#             background-image: url(https://lh3.googleusercontent.com/eld5nhFKpjO9nWYVQuciJ1KLeTZQwiVfSVtZFNcb-njiDY4KNCa5IoK5e3xIVbNI0CILlE57S3Dkj5C7LvCSEmIkGYhoynN9FasHdA=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-b94c682 {
#           background-image: url(https://lh3.googleusercontent.com/eld5nhFKpjO9nWYVQuciJ1KLeTZQwiVfSVtZFNcb-njiDY4KNCa5IoK5e3xIVbNI0CILlE57S3Dkj5C7LvCSEmIkGYhoynN9FasHdA=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-b94c682 {
#             background-image: url(https://lh3.googleusercontent.com/eld5nhFKpjO9nWYVQuciJ1KLeTZQwiVfSVtZFNcb-njiDY4KNCa5IoK5e3xIVbNI0CILlE57S3Dkj5C7LvCSEmIkGYhoynN9FasHdA=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-b94c682 {
#           background-image: url(https://lh3.googleusercontent.com/eld5nhFKpjO9nWYVQuciJ1KLeTZQwiVfSVtZFNcb-njiDY4KNCa5IoK5e3xIVbNI0CILlE57S3Dkj5C7LvCSEmIkGYhoynN9FasHdA=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-b94c682 {
#             background-image: url(https://lh3.googleusercontent.com/eld5nhFKpjO9nWYVQuciJ1KLeTZQwiVfSVtZFNcb-njiDY4KNCa5IoK5e3xIVbNI0CILlE57S3Dkj5C7LvCSEmIkGYhoynN9FasHdA=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-b94c682">
#          <div class="gradient-overlay">
#          </div>
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-b94c682">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__mobile-container">
#         <style>
#          @media screen  {
# .-visible .hero-single-df3d637 {
#           background-image: url(https://lh3.googleusercontent.com/nbYfh50TxwfwtSlsKY53zXccTe_r2KIEaDhX9zOIZ_TUve92of4qcyYXFeXCyR6RdkcsWUsTz73htbyYUWaLCQzWzG8v33iYncKpnQ=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-df3d637 {
#             background-image: url(https://lh3.googleusercontent.com/nbYfh50TxwfwtSlsKY53zXccTe_r2KIEaDhX9zOIZ_TUve92of4qcyYXFeXCyR6RdkcsWUsTz73htbyYUWaLCQzWzG8v33iYncKpnQ=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-df3d637 {
#           background-image: url(https://lh3.googleusercontent.com/nbYfh50TxwfwtSlsKY53zXccTe_r2KIEaDhX9zOIZ_TUve92of4qcyYXFeXCyR6RdkcsWUsTz73htbyYUWaLCQzWzG8v33iYncKpnQ=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-df3d637 {
#             background-image: url(https://lh3.googleusercontent.com/nbYfh50TxwfwtSlsKY53zXccTe_r2KIEaDhX9zOIZ_TUve92of4qcyYXFeXCyR6RdkcsWUsTz73htbyYUWaLCQzWzG8v33iYncKpnQ=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-df3d637 {
#           background-image: url(https://lh3.googleusercontent.com/nbYfh50TxwfwtSlsKY53zXccTe_r2KIEaDhX9zOIZ_TUve92of4qcyYXFeXCyR6RdkcsWUsTz73htbyYUWaLCQzWzG8v33iYncKpnQ=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-df3d637 {
#             background-image: url(https://lh3.googleusercontent.com/nbYfh50TxwfwtSlsKY53zXccTe_r2KIEaDhX9zOIZ_TUve92of4qcyYXFeXCyR6RdkcsWUsTz73htbyYUWaLCQzWzG8v33iYncKpnQ=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-large-tile__desktop-image image-placeholder js-only hero-single-df3d637">
#         </div>
#         <noscript>
#          <div class="module-large-tile__desktop-image hero-single-df3d637">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-large-tile__text-container">
#         <p class="module-large-tile__eyebrow">
#          Our Stories
#         </p>
#         <h4 class="module-large-tile__headline" data-unite-orphan="">
#          The best part about technology is seeing what the world does with it
#         </h4>
#         <p class="module-large-tile__cta">
#          Explore our stories
#         </p>
#        </div>
#       </div>
#      </a>
#     </section>
#     <section class="module-spacer">
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#      <div class="module-spacer--medium module-spacer--color-white">
#      </div>
#     </section>
#     <section class="module module-section h-c-page module-small-tile-collection" data-add-class-on-show="-visible" data-add-class-threshold="100vh" data-section-id="homepage-small-tiles">
#      <div class="h-c-grid module-small-tile-collection__content-container">
#       <a class="h-c-grid__col--6 h-c-grid__col-s--2" href="https://careers.google.com/" target="_blank">
#        <div class="module-small-tile-collection__image-container career-tile">
#         <style>
#          @media screen  {
# .-visible .hero-single-71f3715 {
#           background-image: url(https://lh3.googleusercontent.com/MuEBlmSXEawKPeHNtrU8HbbqJCG4qRW3Ybeq7J1NkHruAz0LKBeL8cB1PdmIZNF974hWAlC5xCV8NvaazusYa5m0wGwDr6ouFQ7H=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-71f3715 {
#             background-image: url(https://lh3.googleusercontent.com/MuEBlmSXEawKPeHNtrU8HbbqJCG4qRW3Ybeq7J1NkHruAz0LKBeL8cB1PdmIZNF974hWAlC5xCV8NvaazusYa5m0wGwDr6ouFQ7H=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-71f3715 {
#           background-image: url(https://lh3.googleusercontent.com/MuEBlmSXEawKPeHNtrU8HbbqJCG4qRW3Ybeq7J1NkHruAz0LKBeL8cB1PdmIZNF974hWAlC5xCV8NvaazusYa5m0wGwDr6ouFQ7H=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-71f3715 {
#             background-image: url(https://lh3.googleusercontent.com/MuEBlmSXEawKPeHNtrU8HbbqJCG4qRW3Ybeq7J1NkHruAz0LKBeL8cB1PdmIZNF974hWAlC5xCV8NvaazusYa5m0wGwDr6ouFQ7H=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-71f3715 {
#           background-image: url(https://lh3.googleusercontent.com/MuEBlmSXEawKPeHNtrU8HbbqJCG4qRW3Ybeq7J1NkHruAz0LKBeL8cB1PdmIZNF974hWAlC5xCV8NvaazusYa5m0wGwDr6ouFQ7H=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-71f3715 {
#             background-image: url(https://lh3.googleusercontent.com/MuEBlmSXEawKPeHNtrU8HbbqJCG4qRW3Ybeq7J1NkHruAz0LKBeL8cB1PdmIZNF974hWAlC5xCV8NvaazusYa5m0wGwDr6ouFQ7H=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-small-tile-collection__image image-placeholder js-only hero-single-71f3715">
#         </div>
#         <noscript>
#          <div class="module-small-tile-collection__image hero-single-71f3715">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-small-tile-collection__text-container">
#         <h4 class="module-small-tile-collection__headline" data-unite-orphan="">
#          <p>
#           Careers at Google
#          </p>
#         </h4>
#         <p class="module-small-tile-collection__cta">
#          Join us
#         </p>
#        </div>
#       </a>
#       <a class="h-c-grid__col--6 h-c-grid__col-s--2" href="locations/" target="_self">
#        <div class="module-small-tile-collection__image-container locations-tile">
#         <style>
#          @media screen  {
# .-visible .hero-single-ebde9fa {
#           background-image: url(https://lh3.googleusercontent.com/VpAJU4nVm9mzKA2H5GVcUR7qJ8aGQhXPg-KaKDSZQDcdDgIpwGLY0b7HgluLUDFh82djR2OUm9hSwC6r4qt8s4MSJuMoiNZjzn-TWw=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-ebde9fa {
#             background-image: url(https://lh3.googleusercontent.com/VpAJU4nVm9mzKA2H5GVcUR7qJ8aGQhXPg-KaKDSZQDcdDgIpwGLY0b7HgluLUDFh82djR2OUm9hSwC6r4qt8s4MSJuMoiNZjzn-TWw=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-ebde9fa {
#           background-image: url(https://lh3.googleusercontent.com/VpAJU4nVm9mzKA2H5GVcUR7qJ8aGQhXPg-KaKDSZQDcdDgIpwGLY0b7HgluLUDFh82djR2OUm9hSwC6r4qt8s4MSJuMoiNZjzn-TWw=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-ebde9fa {
#             background-image: url(https://lh3.googleusercontent.com/VpAJU4nVm9mzKA2H5GVcUR7qJ8aGQhXPg-KaKDSZQDcdDgIpwGLY0b7HgluLUDFh82djR2OUm9hSwC6r4qt8s4MSJuMoiNZjzn-TWw=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-ebde9fa {
#           background-image: url(https://lh3.googleusercontent.com/VpAJU4nVm9mzKA2H5GVcUR7qJ8aGQhXPg-KaKDSZQDcdDgIpwGLY0b7HgluLUDFh82djR2OUm9hSwC6r4qt8s4MSJuMoiNZjzn-TWw=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-ebde9fa {
#             background-image: url(https://lh3.googleusercontent.com/VpAJU4nVm9mzKA2H5GVcUR7qJ8aGQhXPg-KaKDSZQDcdDgIpwGLY0b7HgluLUDFh82djR2OUm9hSwC6r4qt8s4MSJuMoiNZjzn-TWw=w2880-l80-sg-rj-c0xffffff);
#           }
#         }
#         </style>
#         <div class="module-small-tile-collection__image image-placeholder js-only hero-single-ebde9fa">
#         </div>
#         <noscript>
#          <div class="module-small-tile-collection__image hero-single-ebde9fa">
#          </div>
#         </noscript>
#        </div>
#        <div class="module-small-tile-collection__text-container">
#         <h4 class="module-small-tile-collection__headline" data-unite-orphan="">
#          <p>
#           Google locations
#          </p>
#         </h4>
#         <p class="module-small-tile-collection__cta">
#          Find us
#         </p>
#        </div>
#       </a>
#       <a class="h-c-grid__col--6 h-c-grid__col-s--2" href="our-story" target="_self">
#        <div class="module-small-tile-collection__image-container history-tile">
#         <style>
#          @media screen  {
# .-visible .hero-single-4188f27 {
#           background-image: url(https://lh3.googleusercontent.com/tgO6Ew3YkxrCoGvyNpfAWyPe9q_0Zg2WFM8uW5UKzFl6g0QP2EeVpvuOPwZ6_WLbL0NiHQkS8CdaL0k2jtd_YkwdvNZPZ82VAH9nsQ=w600-h350-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen  and (min-resolution: 192dpi) {
# .-visible .hero-single-4188f27 {
#             background-image: url(https://lh3.googleusercontent.com/tgO6Ew3YkxrCoGvyNpfAWyPe9q_0Zg2WFM8uW5UKzFl6g0QP2EeVpvuOPwZ6_WLbL0NiHQkS8CdaL0k2jtd_YkwdvNZPZ82VAH9nsQ=w1200-h700-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 600px) {
# .-visible .hero-single-4188f27 {
#           background-image: url(https://lh3.googleusercontent.com/tgO6Ew3YkxrCoGvyNpfAWyPe9q_0Zg2WFM8uW5UKzFl6g0QP2EeVpvuOPwZ6_WLbL0NiHQkS8CdaL0k2jtd_YkwdvNZPZ82VAH9nsQ=w1080-h378-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 600px) and (min-resolution: 192dpi) {
# .-visible .hero-single-4188f27 {
#             background-image: url(https://lh3.googleusercontent.com/tgO6Ew3YkxrCoGvyNpfAWyPe9q_0Zg2WFM8uW5UKzFl6g0QP2EeVpvuOPwZ6_WLbL0NiHQkS8CdaL0k2jtd_YkwdvNZPZ82VAH9nsQ=w2160-h756-l80-sg-rj-c0xffffff);
#           }
#         }
#
#
#
#
#
#
#       @media screen and (min-width: 1024px) {
# .-visible .hero-single-4188f27 {
#           background-image: url(https://lh3.googleusercontent.com/tgO6Ew3YkxrCoGvyNpfAWyPe9q_0Zg2WFM8uW5UKzFl6g0QP2EeVpvuOPwZ6_WLbL0NiHQkS8CdaL0k2jtd_YkwdvNZPZ82VAH9nsQ=w1440-l80-sg-rj-c0xffffff);
#         }
#       }
#
#         @media screen and (min-width: 1024px) and (min-resolution: 192dpi) {
# .-visible .hero-single-4188f27 {
# ...
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="LinkedIn" data-g-action="social follow - linkedin" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.linkedin.com/company/google" target="_blank">
#           <svg alt="LinkedIn" class="" fill="#000" height="24px" viewBox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg">
#            <path d="M20.447 20.452h-3.554v-5.569c0-1.328-.027-3.037-1.852-3.037-1.853 0-2.136 1.445-2.136 2.939v5.667H9.351V9h3.414v1.561h.046c.477-.9 1.637-1.85 3.37-1.85 3.601 0 4.267 2.37 4.267 5.455v6.286zM5.337 7.433c-1.144 0-2.063-.926-2.063-2.065 0-1.138.92-2.063 2.063-2.063 1.14 0 2.064.925 2.064 2.063 0 1.139-.925 2.065-2.064 2.065zm1.782 13.019H3.555V9h3.564v11.452zM22.225 0H1.771C.792 0 0 .774 0 1.729v20.542C0 23.227.792 24 1.771 24h20.451C23.2 24 24 23.227 24 22.271V1.729C24 .774 23.2 0 22.222 0h.003z">
#            </path>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="language-selector">
#        <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#         <path d="M11.99 2C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2zm6.93 6h-2.95a15.65 15.65 0 00-1.38-3.56A8.03 8.03 0 0118.92 8zM12 4.04c.83 1.2 1.48 2.53 1.91 3.96h-3.82c.43-1.43 1.08-2.76 1.91-3.96zM4.26 14C4.1 13.36 4 12.69 4 12s.1-1.36.26-2h3.38c-.08.66-.14 1.32-.14 2 0 .68.06 1.34.14 2H4.26zm.82 2h2.95c.32 1.25.78 2.45 1.38 3.56A7.987 7.987 0 015.08 16zm2.95-8H5.08a7.987 7.987 0 014.33-3.56A15.65 15.65 0 008.03 8zM12 19.96c-.83-1.2-1.48-2.53-1.91-3.96h3.82c-.43 1.43-1.08 2.76-1.91 3.96zM14.34 14H9.66c-.09-.66-.16-1.32-.16-2 0-.68.07-1.35.16-2h4.68c.09.65.16 1.32.16 2 0 .68-.07 1.34-.16 2zm.25 5.56c.6-1.11 1.06-2.31 1.38-3.56h2.95a8.03 8.03 0 01-4.33 3.56zM16.36 14c.08-.66.14-1.32.14-2 0-.68-.06-1.34-.14-2h3.38c.16.64.26 1.31.26 2s-.1 1.36-.26 2h-3.38z">
#         </path>
#        </svg>
#        <a class="language-selector--lang" data-g-action="language selector - हिन्दी" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="/intl/hi_in/" target="_self">
#         हिन्दी
#        </a>
#       </div>
#      </section>
#      <section class="sitemap">
#       <ul class="cols-row footer-links glue-zippy-set-single" id="footer-sitemap-links">
#        <li class="glue-zippy glue-a-zippy--v-smooth-expand" id="footer-sitemap-about">
#         <h2 class="glue-zippy-btn">
#          More about us
#          <svg alt="" class="icon" height="24px" viewBox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg">
#           <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor">
#           </path>
#          </svg>
#         </h2>
#         <div class="glue-zippy-content">
#          <ul class="links-list">
#           <li>
#            <a data-g-action="more about us - contact-us" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./contact-google/" target="_self">
#             Contact us
#            </a>
#           </li>
#           <li>
#            <a data-g-action="more about us - investor-relations" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://abc.xyz/investor/" target="_blank">
#             Investor relations
#            </a>
#           </li>
#           <li>
#            <a data-g-action="more about us - careers" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://careers.google.com/" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a data-g-action="more about us - locations" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./locations/" target="_self">
#             Locations
#            </a>
#           </li>
#           <li>
#            <a data-g-action="more about us - blog" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.blog.google/" target="_blank">
#             Blog
#            </a>
#           </li>
#           <li>
#            <a data-g-action="more about us - think-with-google" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.thinkwithgoogle.com/intl/en-gb/" target="_blank">
#             Think with Google
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li class="glue-zippy glue-a-zippy--v-smooth-expand" id="footer-sitemap-related">
#         <h2 class="glue-zippy-btn">
#          Press room
#          <svg alt="" class="icon" height="24px" viewBox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg">
#           <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor">
#           </path>
#          </svg>
#         </h2>
#         <div class="glue-zippy-content">
#          <ul class="links-list">
#           <li>
#            <a data-g-action="related information - press-inquiries" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.blog.google/press/" target="_blank">
#             Press enquiries
#            </a>
#           </li>
#           <li>
#            <a data-g-action="related information - images-and-b-roll" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.blog.google/press/" target="_blank">
#             Images &amp; B-roll
#            </a>
#           </li>
#           <li>
#            <a data-g-action="related information - permissions" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.google.com/permissions/" target="_blank">
#             Permissions
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li class="glue-zippy glue-a-zippy--v-smooth-expand" id="footer-sitemap-policy-content">
#         <h2 class="glue-zippy-btn">
#          Policy
#          <svg alt="" class="icon" height="24px" viewBox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg">
#           <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor">
#           </path>
#          </svg>
#         </h2>
#         <div class="glue-zippy-content">
#          <ul class="links-list">
#           <li>
#            <a data-g-action="policy - application-security" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./appsecurity/" target="_self">
#             Application security
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - software-principles" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.google.com/about/software-principles.html" target="_blank">
#             Software principles
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - unwanted-software-policy" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.google.com/about/unwanted-software-policy.html" target="_blank">
#             Unwanted software policy
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - responsible-supply-chain" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.google.com/about/responsible-supply-chain/" target="_blank">
#             Responsible supply chain
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - extended-workforce" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./extended-workforce/" target="_self">
#             Extended workforce
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - conflict-minerals-policy" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://abc.xyz/investor/conflictminerals/" target="_blank">
#             Conflict minerals policy
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - community-guidelines" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./community-guidelines" target="_self">
#             Community Guidelines
#            </a>
#           </li>
#           <li>
#            <a data-g-action="policy - how-google-works" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./how-our-business-works/" target="_self">
#             How our business works
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </section>
#      <section class="foot">
#       <div class="product-logo">
#        <a aria-label="Google" data-g-action="google logo" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="./" target="_self">
#         <svg alt="Google" class="logo-svg" viewBox="0 0 74 24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M9.24 8.19v2.46h5.88c-.18 1.38-.64 2.39-1.34 3.1-.86.86-2.2 1.8-4.54 1.8-3.62 0-6.45-2.92-6.45-6.54s2.83-6.54 6.45-6.54c1.95 0 3.38.77 4.43 1.76L15.4 2.5C13.94 1.08 11.98 0 9.24 0 4.28 0 .11 4.04.11 9s4.17 9 9.13 9c2.68 0 4.7-.88 6.28-2.52 1.62-1.62 2.13-3.91 2.13-5.75 0-.57-.04-1.1-.13-1.54H9.24z" fill="#4285F4">
#          </path>
#          <path d="M25 6.19c-3.21 0-5.83 2.44-5.83 5.81 0 3.34 2.62 5.81 5.83 5.81s5.83-2.46 5.83-5.81c0-3.37-2.62-5.81-5.83-5.81zm0 9.33c-1.76 0-3.28-1.45-3.28-3.52 0-2.09 1.52-3.52 3.28-3.52s3.28 1.43 3.28 3.52c0 2.07-1.52 3.52-3.28 3.52z" fill="#EA4335">
#          </path>
#          <path d="M53.58 7.49h-.09c-.57-.68-1.67-1.3-3.06-1.3C47.53 6.19 45 8.72 45 12c0 3.26 2.53 5.81 5.43 5.81 1.39 0 2.49-.62 3.06-1.32h.09v.81c0 2.22-1.19 3.41-3.1 3.41-1.56 0-2.53-1.12-2.93-2.07l-2.22.92c.64 1.54 2.33 3.43 5.15 3.43 2.99 0 5.52-1.76 5.52-6.05V6.49h-2.42v1zm-2.93 8.03c-1.76 0-3.1-1.5-3.1-3.52 0-2.05 1.34-3.52 3.1-3.52 1.74 0 3.1 1.5 3.1 3.54.01 2.03-1.36 3.5-3.1 3.5z" fill="#4285F4">
#          </path>
#          <path d="M38 6.19c-3.21 0-5.83 2.44-5.83 5.81 0 3.34 2.62 5.81 5.83 5.81s5.83-2.46 5.83-5.81c0-3.37-2.62-5.81-5.83-5.81zm0 9.33c-1.76 0-3.28-1.45-3.28-3.52 0-2.09 1.52-3.52 3.28-3.52s3.28 1.43 3.28 3.52c0 2.07-1.52 3.52-3.28 3.52z" fill="#FBBC05">
#          </path>
#          <path d="M58 .24h2.51v17.57H58z" fill="#34A853">
#          </path>
#          <path d="M68.26 15.52c-1.3 0-2.22-.59-2.82-1.76l7.77-3.21-.26-.66c-.48-1.3-1.96-3.7-4.97-3.7-2.99 0-5.48 2.35-5.48 5.81 0 3.26 2.46 5.81 5.76 5.81 2.66 0 4.2-1.63 4.84-2.57l-1.98-1.32c-.66.96-1.56 1.6-2.86 1.6zm-.18-7.15c1.03 0 1.91.53 2.2 1.28l-5.25 2.17c0-2.44 1.73-3.45 3.05-3.45z" fill="#EA4335">
#          </path>
#         </svg>
#        </a>
#       </div>
#       <ul class="bottom-links">
#        <li>
#         <a data-g-action="bottom footer - help" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://support.google.com?hl=en" target="_blank">
#          <svg alt="" class="svg-icon" fill="#000" height="20px" viewBox="0 0 24 24" width="20px" xmlns="http://www.w3.org/2000/svg">
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#           <path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm1 17h-2v-2h2v2zm2.07-7.75l-.9.92C13.45 12.9 13 13.5 13 15h-2v-.5c0-1.1.45-2.1 1.17-2.83l1.24-1.26c.37-.36.59-.86.59-1.41 0-1.1-.9-2-2-2s-2 .9-2 2H8c0-2.21 1.79-4 4-4s4 1.79 4 4c0 .88-.36 1.68-.93 2.25z">
#           </path>
#          </svg>
#          Help
#         </a>
#        </li>
#        <li>
#         <a data-g-action="bottom footer - privacy" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.google.com/policies/privacy/" target="_blank">
#          Privacy
#         </a>
#        </li>
#        <li>
#         <a data-g-action="bottom footer - terms" data-g-category="site navigation" data-g-label="footer" data-g-nav-link="" href="https://www.google.com/policies/terms/" target="_blank">
#          Terms
#         </a>
#        </li>
#       </ul>
#      </section>
#     </div>
#    </div>
#   </footer>
#   <div class="modal" data-ui-view="modal">
#   </div>
#   <div class="progress" data-ng-if="mainCtrl.isLoading">
#    <span class="progress-bar progress-bar1">
#     <!---->
#    </span>
#    <span class="progress-bar progress-bar2">
#     <!---->
#    </span>
#   </div>
#   <!--[if gt IE 8]><!-->
#   <script id="/modal.html" nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" type="text/ng-template">
#    <div class="modal-overlay">
#     <div data-ui-view="modal-content" class="modal-content"></div>
#     <button class="glue-modal-close" aria-label="close" data-ng-click="modalStateCtrl.closeModal()">  <svg alt=""  class="icon icon-white" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M7.41 18.59L8.83 20 12 16.83 15.17 20l1.41-1.41L12 14l-4.59 4.59zm9.18-13.18L15.17 4 12 7.17 8.83 4 7.41 5.41 12 10l4.59-4.59z"/>
#   </svg>
# </button>
#   </div>
#   </script>
#   <script id="/glue/modal/modal-template.html" nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" type="text/ng-template">
#    <div>
#     <div class="glue-modal-overlay overlay-animate" data-glue-show="modalCtrl.getModalVisible()" data-ng-if="modalCtrl.getModalVisible()">
#       <div class="glue-modal" data-glue-show="modalCtrl.getModalVisible()" role="dialog" tabindex="-1">
#         <div class="glue-modal-content" data-ng-transclude></div>
#         <button class="glue-modal-close" aria-label="close">  <svg alt=""  class="icon icon-white" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M7.41 18.59L8.83 20 12 16.83 15.17 20l1.41-1.41L12 14l-4.59 4.59zm9.18-13.18L15.17 4 12 7.17 8.83 4 7.41 5.41 12 10l4.59-4.59z"/>
#   </svg>
# </button>
#       </div>
#     </div>
#   </div>
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/picturefill/picturefill.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular-touch.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular-animate.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular-sanitize.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/ng_ui_router/release/angular-ui-router.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/gsap/v1_18_0/TweenMax.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/gsap/v1_18_0/plugins/ScrollToPlugin.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/scrollmagic/ScrollMagic.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/scrollmagic/animation.gsap.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/intersectionobserver_polyfill/intersection-observer.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/external_hosted/pixi/pixi.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.google.com/jsapi">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="//www.gstatic.com/feedback/js/help/prod/service/lazy.min.js">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="/assets/js/main.min.js?cache=4bc31b2">
#   </script>
#   <script nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="/assets/js/detect.min.js?cache=c84f19a">
#   </script>
#   <script data-autoload-cookie-consent-bar="true" data-autoload-cookie-consent-bar-intl-code="" nonce="Tk0MJNIvqKfKj2RZ3Le4Rw" src="https://www.gstatic.com/brandstudio/kato/cookie_choice_component/cookie_consent_bar.v3.js">
#   </script>
#   <!--<![endif]-->
#  </body>
# </html>

# %%
soup.find("h1")
# Out:
# <h1>Our mission is to <span class="blue">organise</span> the world’s <span class="red">information</span> and make it <span class="green">universally accessible</span> and <span class="yellow">useful</span>.</h1>

# %%
soup.find_all("img")
# Out:
# [<img alt="Open navigation menu" class="menu-bars" height="24" src="/assets/img/menu.png?cache=38c6aed" width="24"/>,
#  <img alt="Close navigation menu" class="menu-close" height="24" src="/assets/img/close.png?cache=5628868" width="24"/>,
#  <img class="{[::feed.type]}" data-ng-src="/assets/img/{[feed.image_generic]}"/>,
#  <img class="{[::feed.type]} backup-image" data-ng-src="/assets/img/blog-fallback-3.svg"/>,
#  <img alt="" class="icon icon-logo" data-ng-src="/assets/img/social-{[::feed.icon]}-color.svg"/>,
#  <img class="{[::feed.type]}" data-ng-src="/assets/img/{[feed.image_generic]}"/>,
#  <img class="{[::feed.type]} backup-image" data-ng-src="/assets/img/blog-fallback-3.svg"/>,
#  <img alt="" class="icon icon-logo" data-ng-src="/assets/img/social-{[::feed.icon]}-color.svg"/>,
#  <img alt="Previous" src="/assets/img/keyboard-arrow-up-999.svg?cache=911336e"/>,
#  <img alt="Next" src="/assets/img/keyboard-arrow-up-999.svg?cache=911336e"/>,
#  <img class="img lazy-img" data-lazy-img-carousel="" data-lazy-img-delay="" data-lazy-src-bind="{[::doodle.high_res_url]}" data-lazy-threshold="100vh"/>,
#  <img alt="Previous" src="/assets/img/keyboard-arrow-up-999.svg?cache=911336e"/>,
#  <img alt="Next" src="/assets/img/keyboard-arrow-up-999.svg?cache=911336e"/>,
#  <img class="img lazy-img" data-lazy-src-bind="{[::doodleCtrl.doodleHistory[0].high_res_url]}" data-lazy-threshold="100vh"/>]
